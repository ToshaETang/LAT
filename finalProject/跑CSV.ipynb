# %%
#中原大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\中原大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=18/ len(df)
不看超篩數A=18/ len(df)
不看超篩數B=6/ len(df)
不看超篩英=32/ len(df)
不看超篩自=12/ len(df)
不看超篩社=5/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：39.02%
# 社會採計比例：14.63%
# 數A採計比例：53.66%
# 數B採計比例：14.63%
# 英文採計比例：85.37%
# 國文採計比例：63.41%
# 採計科目(含一階篩選方式、倍率、超篩)
# *國、*英、數A、自     1
# *國、*英、自        1
# *國、數A          1
# *國、英           1
# *國、英、*數A       1
# *國、英、*數A、*自    2
# *國、英、*自        1
# 國、*數A          1
# 國、*英           1
# 國、數B           1
# 國、數B、數A        1
# 國、社            1
# 國、英            5
# 國、英、*社         1
# 國、英、數A、數B      1
# 國、英、數A、自       1
# 國、英、數B         1
# 國、英、數B、社       2
# 國、英、社          2
# 彩繪技法、創意表現      1
# 英、數A           4
# 英、數A、自         9
# 英、自            1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：29.27%
# 不看超篩社會採計比例：12.20%
# 不看超篩數A採計比例：43.90%
# 不看超篩數B採計比例：14.63%
# 不看超篩英文採計比例：78.05%
# 不看超篩國文採計比例：43.90%

# %%
#中國醫藥大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\中國醫藥大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=13/ len(df)
不看超篩數A=8/ len(df)
不看超篩數B=1/ len(df)
不看超篩英=15/ len(df)
不看超篩自=16/ len(df)
不看超篩社=1/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：6.25%
# 自然採計比例：100.00%
# 社會採計比例：6.25%
# 數A採計比例：50.00%
# 數B採計比例：6.25%
# 英文採計比例：100.00%
# 國文採計比例：81.25%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、*英、數A、自      1
# 國、數A、社、自、英聽    1
# 國、英、數A、自       4
# 國、英、自          7
# 英、數A、自         2
# 英、數B、自         1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：100.00%
# 不看超篩社會採計比例：6.25%
# 不看超篩數A採計比例：50.00%
# 不看超篩數B採計比例：6.25%
# 不看超篩英文採計比例：93.75%
# 不看超篩國文採計比例：81.25%

# %%
#中山醫學大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\中山醫學大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=45/ len(df)
不看超篩數A=24/ len(df)
不看超篩數B=25/ len(df)
不看超篩英=53/ len(df)
不看超篩自=16/ len(df)
不看超篩社=11/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：1.89%
# 自然採計比例：30.19%
# 社會採計比例：20.75%
# 數A採計比例：45.28%
# 數B採計比例：47.17%
# 英文採計比例：100.00%
# 國文採計比例：84.91%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、數A          8
# 國、英、數A、APCS     1
# 國、英、數A、自       11
# 國、英、數B         11
# 國、英、數B、社        6
# 國、英、數B、社、英聽     1
# 國、英、數B、自        3
# 國、英、社           4
# 英、數A            3
# 英、數A、自          1
# 英、數B            3
# 英、數B、自          1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：30.19%
# 不看超篩社會採計比例：20.75%
# 不看超篩數A採計比例：45.28%
# 不看超篩數B採計比例：47.17%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：84.91%

# %%
#中華大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\中華大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=13/ len(df)
不看超篩數A=9/ len(df)
不看超篩數B=6/ len(df)
不看超篩英=8/ len(df)
不看超篩自=3/ len(df)
不看超篩社=9/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：2.86%
# 自然採計比例：11.43%
# 社會採計比例：25.71%
# 數A採計比例：25.71%
# 數B採計比例：17.14%
# 英文採計比例：22.86%
# 國文採計比例：37.14%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國          8
# 國、數B、社     1
# 國、自        1
# 國、英、數B     1
# 國、英、社      1
# 國、英、自      1
# 數A         8
# 數A、數B、自    1
# 數B         1
# 社          6
# 自          1
# 英          2
# 英、數B       1
# 英、數B、社     1
# 英、英聽       1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：8.57%
# 不看超篩社會採計比例：25.71%
# 不看超篩數A採計比例：25.71%
# 不看超篩數B採計比例：17.14%
# 不看超篩英文採計比例：22.86%
# 不看超篩國文採計比例：37.14%

# %%
#元智大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\元智大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=20/ len(df)
不看超篩數A=10/ len(df)
不看超篩數B=11/ len(df)
不看超篩英=23/ len(df)
不看超篩自=8/ len(df)
不看超篩社=2/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：33.33%
# 社會採計比例：8.33%
# 數A採計比例：45.83%
# 數B採計比例：45.83%
# 英文採計比例：95.83%
# 國文採計比例：83.33%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、數A、自            1
# 國、英               2
# 國、英、數A            2
# 國、英、數A、數B         1
# 國、英、數A、自          3
# 國、英、數A、自、APCS     1
# 國、英、數B            8
# 國、英、數B、素描、創意表現    1
# 國、英、社             1
# 英、數A、自            3
# 英、數B、社            1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：33.33%
# 不看超篩社會採計比例：8.33%
# 不看超篩數A採計比例：41.67%
# 不看超篩數B採計比例：45.83%
# 不看超篩英文採計比例：95.83%
# 不看超篩國文採計比例：83.33%

# %%
#南華大學

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\南華大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=28/ len(df)
不看超篩數A=4/ len(df)
不看超篩數B=5/ len(df)
不看超篩英=3/ len(df)
不看超篩自=5/ len(df)
不看超篩社=18/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：14.29%
# 社會採計比例：51.43%
# 數A採計比例：11.43%
# 數B採計比例：14.29%
# 英文採計比例：8.57%
# 國文採計比例：80.00%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國               9
# 國、數A、數B、社       1
# 國、數A、數B、自       1
# 國、數B            1
# 國、社            12
# 國、自             1
# 國、英             2
# 國、英、數A、數B、自     1
# 數A、數B、自         1
# 社               5
# 自               1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：14.29%
# 不看超篩社會採計比例：51.43%
# 不看超篩數A採計比例：11.43%
# 不看超篩數B採計比例：14.29%
# 不看超篩英文採計比例：8.57%
# 不看超篩國文採計比例：80.00%

# %%
#台北基督學院

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\台北基督學院.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=1/ len(df)
不看超篩數A=0/ len(df)
不看超篩數B=0/ len(df)
不看超篩英=0/ len(df)
不看超篩自=0/ len(df)
不看超篩社=0/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：0.00%
# 社會採計比例：0.00%
# 數A採計比例：0.00%
# 數B採計比例：0.00%
# 英文採計比例：0.00%
# 國文採計比例：100.00%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國    1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：0.00%
# 不看超篩社會採計比例：0.00%
# 不看超篩數A採計比例：0.00%
# 不看超篩數B採計比例：0.00%
# 不看超篩英文採計比例：0.00%
# 不看超篩國文採計比例：100.00%

# %%
#台北醫學大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\台北醫學大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=15/ len(df)
不看超篩數A=13/ len(df)
不看超篩數B=3/ len(df)
不看超篩英=16/ len(df)
不看超篩自=15/ len(df)
不看超篩社=0/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：6.25%
# 自然採計比例：93.75%
# 社會採計比例：0.00%
# 數A採計比例：81.25%
# 數B採計比例：18.75%
# 英文採計比例：100.00%
# 國文採計比例：93.75%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、數A、自       11
# 國、英、數A、自、英聽     1
# 國、英、數B          1
# 國、英、數B、自        2
# 英、數A、自          1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：93.75%
# 不看超篩社會採計比例：0.00%
# 不看超篩數A採計比例：81.25%
# 不看超篩數B採計比例：18.75%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：93.75%

# %%
#國立台南大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立台南大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=19/ len(df)
不看超篩數A=7/ len(df)
不看超篩數B=8/ len(df)
不看超篩英=22/ len(df)
不看超篩自=5/ len(df)
不看超篩社=8/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：4.55%
# 自然採計比例：22.73%
# 社會採計比例：36.36%
# 數A採計比例：40.91%
# 數B採計比例：36.36%
# 英文採計比例：100.00%
# 國文採計比例：86.36%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英                 1
# 國、英、主修、樂理、視唱、聽寫     1
# 國、英、數A              3
# 國、英、數A、APCS         1
# 國、英、數A、自            2
# 國、英、數B              1
# 國、英、數B、社            6
# 國、英、數B、體育百分等級       1
# 國、英、社               2
# 國、英、素描、彩繪技法、創意表現    1
# 英、數A、自              3
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：22.73%
# 不看超篩社會採計比例：36.36%
# 不看超篩數A採計比例：31.82%
# 不看超篩數B採計比例：36.36%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：86.36%

# %%
#國立台灣海洋大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立台灣海洋大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=19/ len(df)
不看超篩數A=18/ len(df)
不看超篩數B=6/ len(df)
不看超篩英=24/ len(df)
不看超篩自=16/ len(df)
不看超篩社=5/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：66.67%
# 社會採計比例：20.83%
# 數A採計比例：75.00%
# 數B採計比例：25.00%
# 英文採計比例：100.00%
# 國文採計比例：79.17%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、數A、自     13
# 國、英、數B        1
# 國、英、數B、社      5
# 英、數A          1
# 英、數A、APCS     1
# 英、數A、自        3
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：66.67%
# 不看超篩社會採計比例：20.83%
# 不看超篩數A採計比例：75.00%
# 不看超篩數B採計比例：25.00%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：79.17%

# %%
#國立嘉義大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立嘉義大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=37/ len(df)
不看超篩數A=19/ len(df)
不看超篩數B=13/ len(df)
不看超篩英=36/ len(df)
不看超篩自=19/ len(df)
不看超篩社=11/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：2.44%
# 自然採計比例：51.22%
# 社會採計比例：26.83%
# 數A採計比例：46.34%
# 數B採計比例：31.71%
# 英文採計比例：97.56%
# 國文採計比例：90.24%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、數B、社、自          1
# 國、英、主修、樂理、聽寫      1
# 國、英、數A            1
# 國、英、數A、自         14
# 國、英、數B            7
# 國、英、數B、社          5
# 國、英、社             4
# 國、英、社、素描、彩繪技法     1
# 國、英、自             3
# 英、數A、APCS         1
# 英、數A、自            3
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：46.34%
# 不看超篩社會採計比例：26.83%
# 不看超篩數A採計比例：46.34%
# 不看超篩數B採計比例：31.71%
# 不看超篩英文採計比例：87.80%
# 不看超篩國文採計比例：90.24%

# %%
#國立屏東大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立屏東大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=29/ len(df)
不看超篩數A=9/ len(df)
不看超篩數B=14/ len(df)
不看超篩英=32/len(df)
不看超篩自=8/ len(df)
不看超篩社=15/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：2.94%
# 自然採計比例：23.53%
# 社會採計比例：47.06%
# 數A採計比例：26.47%
# 數B採計比例：41.18%
# 英文採計比例：94.12%
# 國文採計比例：82.35%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、社            1
# 國、英            1
# 國、英、主修         1
# 國、英、數A         3
# 國、英、數A、自       1
# 國、英、數B         4
# 國、英、數B、社       9
# 國、英、數B、自       1
# 國、英、社          5
# 國、英、社、英聽       1
# 國、英、素描、彩繪技法    1
# 數A、自           1
# 英、數A、自         4
# 英、自            1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：23.53%
# 不看超篩社會採計比例：44.12%
# 不看超篩數A採計比例：26.47%
# 不看超篩數B採計比例：41.18%
# 不看超篩英文採計比例：94.12%
# 不看超篩國文採計比例：85.29%

# %%
#國立聯合大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立聯合大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=17/ len(df)
不看超篩數A=12/ len(df)
不看超篩數B=5/ len(df)
不看超篩英=19/ len(df)
不看超篩自=7/ len(df)
不看超篩社=3/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：38.10%
# 社會採計比例：14.29%
# 數A採計比例：61.90%
# 數B採計比例：23.81%
# 英文採計比例：95.24%
# 國文採計比例：80.95%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、數A、自         1
# 國、英            2
# 國、英、數A         2
# 國、英、數A、自       5
# 國、英、數B         3
# 國、英、數B、APCS    1
# 國、英、數B、社       1
# 國、英、社          2
# 英、數A           1
# 英、數A、APCS      1
# 英、數A、自         2
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：33.33%
# 不看超篩社會採計比例：14.29%
# 不看超篩數A採計比例：57.14%
# 不看超篩數B採計比例：23.81%
# 不看超篩英文採計比例：90.48%
# 不看超篩國文採計比例：80.95%

# %%
#國立臺灣師範大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\國立臺灣師範大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)

不看超篩國=29/ len(df)
不看超篩數A=11/ len(df)
不看超篩數B=10/ len(df)
不看超篩英=33/ len(df)
不看超篩自=11/ len(df)
不看超篩社=10/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：5.41%
# 自然採計比例：35.14%
# 社會採計比例：45.95%
# 數A採計比例：32.43%
# 數B採計比例：35.14%
# 英文採計比例：97.30%
# 國文採計比例：86.49%
# 採計科目(含一階篩選方式、倍率、超篩)
# *國、*英、*社、彩繪技法、素描          1
# *國、*英、*社、彩繪技法、素描、水墨書畫     1
# *國、英、*數A、自                1
# *數、自                      1
# *英、數A、自                   1
# 國、英                       4
# 國、英'、數B                   1
# 國、英'、數B、社                 1
# 國、英、*數B、*社                2
# 國、英、*數B、*社、英聽             1
# 國、英、主修                    1
# 國、英、數A                    1
# 國、英、數A、*社、素描、彩繪技法、創意表現    1
# 國、英、數A、*自                 1
# 國、英、數A、自                  5
# 國、英、數B                    1
# 國、英、數B、社                  5
# 國、英、數B、社、英聽               1
# 國、英、社                     3
# 國、英、社、自、體育百分等級            1
# 英、數A、自                    2
# 英、數B、自                    1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：29.73%
# 不看超篩社會採計比例：27.03%
# 不看超篩數A採計比例：29.73%
# 不看超篩數B採計比例：27.03%
# 不看超篩英文採計比例：89.19%
# 不看超篩國文採計比例：78.38%

# %%
#康寧大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\康寧大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=2/ len(df)
不看超篩數A=0/ len(df)
不看超篩數B=0/ len(df)
不看超篩英=2/ len(df)
不看超篩自=0/ len(df)
不看超篩社=2/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：0.00%
# 社會採計比例：100.00%
# 數A採計比例：0.00%
# 數B採計比例：0.00%
# 英文採計比例：100.00%
# 國文採計比例：100.00%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、社    2
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：0.00%
# 不看超篩社會採計比例：100.00%
# 不看超篩數A採計比例：0.00%
# 不看超篩數B採計比例：0.00%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：100.00%

# %%
#明道大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\明道大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=8/ len(df)
不看超篩數A=1/ len(df)
不看超篩數B=4/ len(df)
不看超篩英=4/ len(df)
不看超篩自=1/ len(df)
不看超篩社=0/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：11.11%
# 社會採計比例：0.00%
# 數A採計比例：11.11%
# 數B採計比例：44.44%
# 英文採計比例：44.44%
# 國文採計比例：88.89%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國         2
# 國、數B      2
# 國、英       2
# 國、英、數B    2
# 數A、自      1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：11.11%
# 不看超篩社會採計比例：0.00%
# 不看超篩數A採計比例：11.11%
# 不看超篩數B採計比例：44.44%
# 不看超篩英文採計比例：44.44%
# 不看超篩國文採計比例：88.89%

# %%
#東吳大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\東吳大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=13/ len(df)
不看超篩數A=5/ len(df)
不看超篩數B=9/ len(df)
不看超篩英=16/ len(df)
不看超篩自=3/ len(df)
不看超篩社=8/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：4.35%
# 自然採計比例：13.04%
# 社會採計比例：39.13%
# 數A採計比例：21.74%
# 數B採計比例：39.13%
# 英文採計比例：78.26%
# 國文採計比例：65.22%
# 採計科目(含一階篩選方式、倍率、超篩)
# *國、*英、數B、社        1
# *國、英、數B           1
# *英、數A、自           1
# 國、社               3
# 國、英               1
# 國、英、主修            1
# 國、英、數A            1
# 國、英、數A、數B、社、英聽    1
# 國、英、數B            2
# 國、英、社             4
# 數A                1
# 數A、自              1
# 英、數B              4
# 英、自               1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：13.04%
# 不看超篩社會採計比例：34.78%
# 不看超篩數A採計比例：21.74%
# 不看超篩數B採計比例：39.13%
# 不看超篩英文採計比例：69.57%
# 不看超篩國文採計比例：56.52%

# %%
#玄奘大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\玄奘大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=10/ len(df)
不看超篩數A=0/ len(df)
不看超篩數B=0/ len(df)
不看超篩英=0/ len(df)
不看超篩自=0/ len(df)
不看超篩社=1/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：0.00%
# 社會採計比例：9.09%
# 數A採計比例：0.00%
# 數B採計比例：0.00%
# 英文採計比例：0.00%
# 國文採計比例：90.91%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國    10
# 社     1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：0.00%
# 不看超篩社會採計比例：9.09%
# 不看超篩數A採計比例：0.00%
# 不看超篩數B採計比例：0.00%
# 不看超篩英文採計比例：0.00%
# 不看超篩國文採計比例：90.91%

# %%
#逢甲大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\逢甲大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=45/ len(df)
不看超篩數A=24/ len(df)
不看超篩數B=25/ len(df)
不看超篩英=53/ len(df)
不看超篩自=16/ len(df)
不看超篩社=9/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：1.89%
# 自然採計比例：30.19%
# 社會採計比例：20.75%
# 數A採計比例：45.28%
# 數B採計比例：47.17%
# 英文採計比例：100.00%
# 國文採計比例：84.91%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、數A          8
# 國、英、數A、APCS     1
# 國、英、數A、自       11
# 國、英、數B         11
# 國、英、數B、社        6
# 國、英、數B、社、英聽     1
# 國、英、數B、自        3
# 國、英、社           4
# 英、數A            3
# 英、數A、自          1
# 英、數B            3
# 英、數B、自          1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：30.19%
# 不看超篩社會採計比例：16.98%
# 不看超篩數A採計比例：45.28%
# 不看超篩數B採計比例：47.17%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：84.91%

# %%
#銘傳大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\銘傳大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=58/ len(df)
不看超篩數A=2/ len(df)
不看超篩數B=17/ len(df)
不看超篩英=47/ len(df)
不看超篩自=3/ len(df)
不看超篩社=41/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：4.84%
# 社會採計比例：67.74%
# 數A採計比例：6.45%
# 數B採計比例：27.42%
# 英文採計比例：74.19%
# 國文採計比例：93.55%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、數A          1
# 國、數B          2
# 國、數B、APCS     2
# 國、數B、社        2
# 國、社           8
# 國、自           1
# 國、英           6
# 國、英、數A、數B     1
# 國、英、數B        4
# 國、英、數B、社      5
# 國、英、社        24
# 國、英、自         2
# 英             1
# 英、數B、社        1
# 英、社           2
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：4.84%
# 不看超篩社會採計比例：66.13%
# 不看超篩數A採計比例：3.23%
# 不看超篩數B採計比例：27.42%
# 不看超篩英文採計比例：75.81%
# 不看超篩國文採計比例：93.55%

# %%
#長庚大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\長庚大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=14/ len(df)
不看超篩數A=18/ len(df)
不看超篩數B=3/ len(df)
不看超篩英=22/ len(df)
不看超篩自=16/ len(df)
不看超篩社=0/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：72.73%
# 社會採計比例：0.00%
# 數A採計比例：81.82%
# 數B採計比例：13.64%
# 英文採計比例：100.00%
# 國文採計比例：63.64%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、英、數A       2
# 國、英、數A、數B    2
# 國、英、數A、自     7
# 國、英、數B       1
# 國、英、自        2
# 英、數A         1
# 英、數A、自       6
# 英、自          1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：72.73%
# 不看超篩社會採計比例：0.00%
# 不看超篩數A採計比例：81.82%
# 不看超篩數B採計比例：13.64%
# 不看超篩英文採計比例：100.00%
# 不看超篩國文採計比例：63.64%

# %%
#長榮大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\長榮大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=74/ len(df)
不看超篩數A=0/ len(df)
不看超篩數B=17/ len(df)
不看超篩英=38/ len(df)
不看超篩自=12/ len(df)
不看超篩社=43/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：15.58%
# 社會採計比例：54.55%
# 數A採計比例：1.30%
# 數B採計比例：22.08%
# 英文採計比例：51.95%
# 國文採計比例：96.10%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國               6
# 國、數B            2
# 國、數B、社          4
# 國、社            14
# 國、素描            1
# 國、自             8
# 國、英             7
# 國、英、數B          6
# 國、英、數B、APCS     1
# 國、英、數B、社        4
# 國、英、社          17
# 國、英、自           4
# 社               2
# 英、社             1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：15.58%
# 不看超篩社會採計比例：55.84%
# 不看超篩數A採計比例：0.00%
# 不看超篩數B採計比例：22.08%
# 不看超篩英文採計比例：49.35%
# 不看超篩國文採計比例：96.10%

# %%
#靜宜大學.csv

import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\靜宜大學.csv", encoding="utf-8")

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
國count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
數Bcount=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
社count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
自count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
英聽count=(df['採計科目(含一階篩選方式、倍率、超篩)'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('採計科目(含一階篩選方式、倍率、超篩)')['採計科目(含一階篩選方式、倍率、超篩)'].count()
print(採計counts)


不看超篩國=26/ len(df)
不看超篩數A=0/ len(df)
不看超篩數B=8/ len(df)
不看超篩英=23/ len(df)
不看超篩自=3/ len(df)
不看超篩社=5/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：7.41%
# 自然採計比例：11.11%
# 社會採計比例：18.52%
# 數A採計比例：7.41%
# 數B採計比例：29.63%
# 英文採計比例：85.19%
# 國文採計比例：96.30%
# 採計科目(含一階篩選方式、倍率、超篩)
# 國、數B         1
# 國、數B、APCS    1
# 國、社          1
# 國、自          1
# 國、英          9
# 國、英、數B       5
# 國、英、社        4
# 國、英、自        2
# 國、英、英聽       2
# 英、數B、APCS    1
# Name: 採計科目(含一階篩選方式、倍率、超篩), dtype: int64
# 不看超篩自然採計比例：11.11%
# 不看超篩社會採計比例：18.52%
# 不看超篩數A採計比例：0.00%
# 不看超篩數B採計比例：29.63%
# 不看超篩英文採計比例：85.19%
# 不看超篩國文採計比例：96.30%
