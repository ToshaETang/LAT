# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\CSMU2.csv", encoding="utf-8")

採計counts = df.groupby('subject')['subject'].count()
國count=(df['subject'].str.contains('國')).sum()
國countratio=國count / len(df)
採計counts = df.groupby('subject')['subject'].count()
英count=(df['subject'].str.contains('英')).sum()
英countratio=英count / len(df)
數Acount=(df['subject'].str.contains('A')).sum()
數Acountratio=數Acount / len(df)
數Bcounts = df.groupby('subject')['subject'].count()
數Bcount=(df['subject'].str.contains('B')).sum()
數Bcountratio=數Bcount / len(df)
社counts = df.groupby('subject')['subject'].count()
社count=(df['subject'].str.contains('社')).sum()
社countratio=社count / len(df)
自counts = df.groupby('subject')['subject'].count()
自count=(df['subject'].str.contains('自')).sum()
自countratio=自count / len(df)
英聽counts = df.groupby('subject')['subject'].count()
英聽count=(df['subject'].str.contains('聽')).sum()
英聽countratio=英聽count / len(df)
print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('自然採計比例：{:.2f}%'.format(自countratio*100))
print('社會採計比例：{:.2f}%'.format(社countratio*100))
print('數A採計比例：{:.2f}%'.format(數Acountratio*100))
print('數B採計比例：{:.2f}%'.format(數Bcountratio*100))
print('英文採計比例：{:.2f}%'.format(英countratio*100))
print('國文採計比例：{:.2f}%'.format(國countratio*100))

採計counts = df.groupby('subject')['subject'].count()
print(採計counts)


不看超篩國=/ len(df)
不看超篩數A=/ len(df)
不看超篩數B=/ len(df)
不看超篩英=/ len(df)
不看超篩自=/ len(df)
不看超篩社=/ len(df)

#print('英聽採計比例：{:.2f}%'.format(英聽countratio*100))
print('不看超篩自然採計比例：{:.2f}%'.format(不看超篩自*100))
print('不看超篩社會採計比例：{:.2f}%'.format(不看超篩社*100))
print('不看超篩數A採計比例：{:.2f}%'.format(不看超篩數A*100))
print('不看超篩數B採計比例：{:.2f}%'.format(不看超篩數B*100))
print('不看超篩英文採計比例：{:.2f}%'.format(不看超篩英*100))
print('不看超篩國文採計比例：{:.2f}%'.format(不看超篩國*100))
# Out:
# 英聽採計比例：0.00%
# 自然採計比例：80.95%
# 社會採計比例：9.52%
# 數A採計比例：66.67%
# 數B採計比例：14.29%
# 英文採計比例：95.24%
# 國文採計比例：80.95%
# subject
# 國、數A、自          1
# 國、英             1
# 國、英、數A          1
# 國、英、數A、數B、自     1
# 國、英、數A、自       10
# 國、英、數B、社        1
# 國、英、社、自         1
# 國、英、自           1
# 英、數A、自          1
# 英、數B            1
# 英、自             2
# Name: subject, dtype: int64

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Tosha.E.T\Documents\GitHub\LAT\finalProject\KEYI_university111\CSMU2.csv", encoding="utf-8")

df
# Out:
#                 科系      subject
# 0              醫學系     國、英、數A、自
# 1             牙醫學系     國、英、數A、自
# 2           物理治療學系      國、英、社、自
# 3           職能治療學系     國、英、數A、自
# 4   語言治療與聽力學系語言治療組     國、英、數A、自
# 5     語言治療與聽力學系聽力組     國、英、數A、自
# 6         生物醫學科學學系  國、英、數A、數B、自
# 7             視光學系          英、自
# 8       醫學影像暨放射科學系     國、英、數A、自
# 9             心理學系       國、英、數A
# 10            營養學系        國、英、自
# 11        職業安全衛生學系     國、英、數A、自
# 12         醫學應用化學系       國、數A、自
# 13      健康產業科技管理學系       英、數A、自
# 14            護理學系     國、英、數A、自
# 15     醫學檢驗暨生物技術學系          英、自
# 16        應用外國語言學系          國、英
# 17          公共衛生學系     國、英、數A、自
# 18     醫學社會暨社會工作學系     國、英、數B、社
# 19          醫學資訊學系     國、英、數A、自
# 20      醫療產業科技管理學系         英、數B
